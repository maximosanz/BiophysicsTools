# %%
import matplotlib.pyplot as plt
from Fluorescence_PCA import Fluorescence_Data

# %% [markdown]
# ### Settings to make the plots larger

# %%
plt.rcParams['figure.figsize'] = [9,6]

# %% [markdown]
# ### Loading the data

# %%
Data = Fluorescence_Data("TEMPLATE.csv")

# %% [markdown]
# ### Perform and plot the PCA

# %%
Data.do_PCA()
Data.plot_PCA()

# %% [markdown]
# ### Evaluate the contribution of each compound to the PCA

# %%
Data.plot_Compound_contribution()

# %% [markdown]
# ### Re-run the PCA with additional options
# e.g. use only some compounds or some samples

# %%
Data.do_PCA(use_compounds=["X3","X4","X6"])
Data.plot_PCA(savefig="Figures/PCA.jpg")

# %%
Data.plot_Compound_contribution(savefig="Figures/Compound_contribution.jpg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b447820e82a7> in <module>
# ----> 1 Data.plot_Compound_contribution(savefig="Figures/Compound_contribution.jpg")
#
# ~/work/github/BiophysicsTools/Fluorescence_PCA/Fluorescence_PCA.py in plot_Compound_contribution(self, savefig)
#      63     def plot_Compound_contribution(self,savefig=''):
#      64         if savefig:
# ---> 65             savefigfn = savefig.split('.')[:-1].join('.')
#      66             savefigsuf = savefig.split('.')[-1]
#      67         components = self.pca.components_
#
# AttributeError: 'list' object has no attribute 'join'

# %% [markdown]
# ### Plot individual emission spectra

# %%
Data.plot_spectra("X4",plot_sample=["Buffer","PROTEIN A","PROTEIN B"],savefig="Figures/Emission.jpg")
Data.plot_spectra("X3",plot_sample=["Buffer","PROTEIN A","PROTEIN B"])
